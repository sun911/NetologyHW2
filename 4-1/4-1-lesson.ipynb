# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import date

# %%
pd.Series([1, 1, 2, 3, 5, 8])
# Out:
# 0    1
# 1    1
# 2    2
# 3    3
# 4    5
# 5    8
# dtype: int64

# %%
pd.Series([1, 1, 2, 3, 5, 8, 13.5])
# Out:
# 0     1.0
# 1     1.0
# 2     2.0
# 3     3.0
# 4     5.0
# 5     8.0
# 6    13.5
# dtype: float64

# %%
weather = pd.DataFrame({
    'City': ['MSK', 'SPB', 'NN', 'MSK', 'SPB'],
    'Temperature': [-3, +2, -2, -3, +2],
    'State' : ['Cloudy', 'Clear', 'Snow', 'Cloudy', 'Clear'],
    'Date': [date(2017, 1, 1), date(2017, 1, 1), date(2017, 1, 1), date(2017, 1, 2), date(2017, 1, 2)]
})
weather
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Date</th>
#       <th>State</th>
#       <th>Temperature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>MSK</td>
#       <td>2017-01-01</td>
#       <td>Cloudy</td>
#       <td>-3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>SPB</td>
#       <td>2017-01-01</td>
#       <td>Clear</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NN</td>
#       <td>2017-01-01</td>
#       <td>Snow</td>
#       <td>-2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>MSK</td>
#       <td>2017-01-02</td>
# ...

# %%
weather.City
# Out:
# 0    MSK
# 1    SPB
# 2     NN
# 3    MSK
# 4    SPB
# Name: City, dtype: object

# %%
import os
datapath = os.getcwd()
print(datapath + '\\4-1\\names\yob1880.txt')
x = pd.read_csv(datapath + '\\4-1\\names\yob1880.txt')
pd.read_csv(datapath + '\\4-1\\names\yob1880.txt').head(10)
# Out:
# H:\Python\NetologyHW\4-1\names\yob1880.txt
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Mary</th>
#       <th>F</th>
#       <th>7065</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Anna</td>
#       <td>F</td>
#       <td>2604</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Emma</td>
#       <td>F</td>
#       <td>2003</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Elizabeth</td>
#       <td>F</td>
#       <td>1939</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Minnie</td>
#       <td>F</td>
#       <td>1746</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Margaret</td>
# ...

# %%
names = pd.read_csv(
    datapath + '\\4-1\\names\yob2000.txt',
    names=['Name', 'Gender', 'Count']
)
names.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Gender</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Emily</td>
#       <td>F</td>
#       <td>25953</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Hannah</td>
#       <td>F</td>
#       <td>23078</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Madison</td>
#       <td>F</td>
#       <td>19967</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Ashley</td>
#       <td>F</td>
#       <td>17996</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Sarah</td>
#       <td>F</td>
# ...

# %%
names[:10].to_csv('temp.csv', index=False)

# %%
names.query('Count < 10')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Gender</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9869</th>
#       <td>Aailyah</td>
#       <td>F</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>9870</th>
#       <td>Aalia</td>
#       <td>F</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>9871</th>
#       <td>Aaminah</td>
#       <td>F</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>9872</th>
#       <td>Aasha</td>
#       <td>F</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>9873</th>
#       <td>Aasia</td>
#       <td>F</td>
#       <td>9</td>
# ...

# %%
names.query('(Count > 20000 | Count < 10) & Gender == "M"')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Gender</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>17653</th>
#       <td>Jacob</td>
#       <td>M</td>
#       <td>34470</td>
#     </tr>
#     <tr>
#       <th>17654</th>
#       <td>Michael</td>
#       <td>M</td>
#       <td>32033</td>
#     </tr>
#     <tr>
#       <th>17655</th>
#       <td>Matthew</td>
#       <td>M</td>
#       <td>28572</td>
#     </tr>
#     <tr>
#       <th>17656</th>
#       <td>Joshua</td>
#       <td>M</td>
#       <td>27536</td>
#     </tr>
#     <tr>
#       <th>17657</th>
#       <td>Christopher</td>
# ...

# %%
names.Count > 15000
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 29734    False
# 29735    False
# 29736    False
# 29737    False
# 29738    False
# 29739    False
# 29740    False
# 29741    False
# 29742    False
# 29743    False
# 29744    False
# 29745    False
# 29746    False
# 29747    False
# 29748    False
# 29749    False
# 29750    False
# 29751    False
# 29752    False
# 29753    False
# 29754    False
# 29755    False
# 29756    False
# 29757    False
# 29758    False
# 29759    False
# 29760    False
# ...

# %%
names[(names.Name.str.startswith("M")) & (names.Count > 3000)].head(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Gender</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>Madison</td>
#       <td>F</td>
#       <td>19967</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Megan</td>
#       <td>F</td>
#       <td>11434</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Morgan</td>
#       <td>F</td>
#       <td>9502</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>Maria</td>
#       <td>F</td>
#       <td>6851</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>Mackenzie</td>
#       <td>F</td>
# ...

# %%
names.sort_values(by=['Name', 'Count'], ascending=True).head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Gender</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>26755</th>
#       <td>Aadam</td>
#       <td>M</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>27996</th>
#       <td>Aadarsh</td>
#       <td>M</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24482</th>
#       <td>Aadil</td>
#       <td>M</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>23570</th>
#       <td>Aaditya</td>
#       <td>M</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>26756</th>
#       <td>Aahil</td>
#       <td>M</td>
# ...

# %%
def foo(bar):
    print("bar")
    print(bar)
names.head(3).apply(foo)
# Out:
# bar
# 0      Emily
# 1     Hannah
# 2    Madison
# Name: Name, dtype: object
# bar
# 0    F
# 1    F
# 2    F
# Name: Gender, dtype: object
# bar
# 0    25953
# 1    23078
# 2    19967
# Name: Count, dtype: object
# Name      None
# Gender    None
# Count     None
# dtype: object

# %%
def make_df(cols, ind):
    """Быстро создаем объект DataFrame"""
    data = {c: [str(c) + str(i) for i in ind] 
            for c in cols}
    return pd.DataFrame(data, ind)

# %%
df1 = make_df('AB', [1, 2])
df2 = make_df('AB', [3, 4])
print(df1); print(df2); print(pd.concat([df1, df2]))
# Out:
#     A   B
# 1  A1  B1
# 2  A2  B2
#     A   B
# 3  A3  B3
# 4  A4  B4
#     A   B
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4
